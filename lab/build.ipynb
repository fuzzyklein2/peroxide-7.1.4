# %%
import home
# Out:
# 📁 Current working directory: /home/fuzzy/projects/peroxide

# %%
from tools import *

# %%
from tools.glob4meson.glob4meson import glob4meson

# %%
glob4meson()
# Out:
# Found 1 source files:
#   source/audio.cpp
# meson.build updated with 1 source files.

# %%
# %%bash
# # Start from scratch:
# rm -rf build
# meson setup build
# Out:
# The Meson build system
# Version: 1.3.2
# Source dir: /home/fuzzy/projects/peroxide
# Build dir: /home/fuzzy/projects/peroxide/build
# Build type: native build
# Project name: peroxide
# Project version: 0.1.0
# C++ compiler for the host machine: c++ (gcc 13.3.0 "c++ (Ubuntu 13.3.0-6ubuntu2~24.04.1) 13.3.0")
# C++ linker for the host machine: c++ ld.bfd 2.42
# Host machine cpu family: x86_64
# Host machine cpu: x86_64
# Build targets in project: 1
#
# Found ninja-1.11.1 at /usr/bin/ninja

# %%
# %%bash
# meson configure build --buildtype=debug
# meson compile -C build
# Out:
# ninja: Entering directory `/home/fuzzy/projects/peroxide/build'
# [1/2] Compiling C++ object libperoxide.a.p/source_audio.cpp.o
# [2/2] Linking static target libperoxide.a
# INFO: autodetecting backend as ninja
# INFO: calculating backend command to run: /usr/bin/ninja -C /home/fuzzy/projects/peroxide/build
