# %% [markdown]
# # Documentation

# %%
import home
from tools import *
# Out:
# 📁 Current working directory: /home/fuzzy/projects/peroxide

# %% [markdown]
# ## Make a docstring

# %%
s = (rdocify("""
This is just a test.
""", file_doc=False))

# %%
print(s)
# Out:
# /// This is just a test.
