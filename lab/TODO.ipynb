# %% [markdown]
# # Things To Do

# %%
import home
from tools import *
# Out:
# 📁 Current working directory: /home/fuzzy/projects/peroxide

# %%
PATTERN = r'TODO:'
FILES = './src/*.rs'

# %%
import subprocess

# %%
# !ls src
# Out:
# config.rs     files.rs	  logging.rs  peroxide.rs
# constants.rs  getargs.rs  main.rs     utilities.rs

# %%
CMD_LINE = f"grep -E -n {PATTERN} {FILES}".split()

# %%
CMD_LINE = ['grep', '-E', '-n', 'TODO', 'src/*.rs']

# %%
CMD_LINE = f"grep -R {PATTERN} --include='*.rs'".split()

# %%
p = subprocess.run(CMD_LINE,
                   capture_output=True,
                   text=True,
                  )

# %%
from pathlib import Path
import subprocess

files = [
    p for p in Path(".").rglob("*.rs")
    if not any(part.startswith(".") for part in p.parts)
]

p = subprocess.run(["grep", "-n", f'{PATTERN}', *files], capture_output=True, text=True)

# %%
print(p.stderr)

# %%
print(p.stdout)
# Out:
# src/peroxide.rs:2:// TODO: Get this file to run and run it with -h ==> SYNOPSIS
# src/peroxide.rs:3:// TODO: Write some unit tests
# src/peroxide.rs:50:    // TODO: Find or write a function to determine if a directory is empty.
# src/peroxide.rs:137:        // TODO: Test using an Option as Pattern::repeat_count
# src/peroxide.rs:165:// TODO: Implement Pattern::from_json_value
# src/peroxide.rs:229:        // TODO: refresh the label
# src/peroxide.rs:501:    // TODO: Implement the curses style interface in the comment below.

# %%
# %%bash
# grep -E -n TODO src/*.rs
# Out:
# src/peroxide.rs:2:// TODO: Get this file to run and run it with -h ==> SYNOPSIS
# src/peroxide.rs:3:// TODO: Write some unit tests
# src/peroxide.rs:50:    // TODO: Find or write a function to determine if a directory is empty.
# src/peroxide.rs:200:        // TODO: refresh the label
# src/peroxide.rs:438:    // TODO: Implement the curses style interface in the comment below.

# %%
lines = p.stdout.split(NEWLINE)

# %%
len(lines)
# Out:
# 6
