# %% [markdown]
# # Errors

# %%
import home
from tools import *
# Out:
# 📁 Current working directory: /home/fuzzy/projects/peroxide

# %%
import re
import subprocess

# %%
CMD_LINE = "cargo build"

# %%
p = subprocess.run(CMD_LINE.split(),
                   capture_output=True,
                   text=True,
                  )

# %%
print(p.stderr)
# Out:
#    Compiling peroxide v0.1.0 (/home/fuzzy/projects/peroxide)
# error: unexpected closing delimiter: `}`
#    --> src/peroxide.rs:497:1
#     |
# 406 |         match pattern.value {
#     |                             - the nearest open delimiter
# 407 |             JsonValue::Array(a) => self.parse_items(&a), &pattern.repeat_count),
#     |                                                                               - missing open `(` for this delimiter
# ...
# 497 | } // impl Player
#     | ^ unexpected closing delimiter
#
# error: could not compile `peroxide` (bin "peroxide") due to 1 previous error

# %%
print(p.stdout)

# %%
lines = p.stderr.split('\n')
